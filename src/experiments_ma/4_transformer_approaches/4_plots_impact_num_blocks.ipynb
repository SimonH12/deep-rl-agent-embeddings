# %%
import os, sys
import torch
import matplotlib.pyplot as plt
import seaborn as sns

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1

plt.rcParams.update({
    'figure.dpi': 300,
    'axes.labelsize': 30.0,
    'axes.titlesize': 30.0,
    'axes.labelweight': 'normal',
    'axes.linewidth': 1.25,
    'legend.fontsize': 25,
    'legend.title_fontsize': 18.0,
    'xtick.labelsize': 30,
    'ytick.labelsize': 30,
    'lines.linewidth': 2.0,
    'lines.markersize': 6.0,
    'grid.color': '.8',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
})

if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig
from src.utils import ExperimentUtils

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/4_set_transformer_og_blocks.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of blocks')
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/4_set_transformer_blocks.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of blocks')
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/4_isab_transformer_blocks.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of blocks')
print(suite_utils.create_table_with_confidence())
# Out:
#   Experiment  training_time training_memory_usage       inference_time  \
# 0  count = 1   56.72 ± 0.64   0.00e+00 ± 0.00e+00  4.43e-04 ± 1.02e-05
# 1  count = 2   86.35 ± 0.52   0.00e+00 ± 0.00e+00  4.81e-04 ± 1.95e-05
# 2  count = 3  113.84 ± 0.33   0.00e+00 ± 0.00e+00  4.64e-04 ± 1.12e-05
#
#     mean_rewards          loss              flops         parameters
# 0   99.63 ± 2.17  -0.45 ± 0.16   44.60 ± 4.34e-15   48.38 ± 0.00e+00
# 1  102.88 ± 1.82  -0.75 ± 0.16  125.80 ± 0.00e+00  115.08 ± 0.00e+00
# 2  102.76 ± 3.88  -0.86 ± 0.11  207.00 ± 0.00e+00  181.76 ± 0.00e+00

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/4_sab_transformer_blocks.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of blocks')
print(suite_utils.create_table_with_confidence())
# Out:
#   Experiment  training_time training_memory_usage       inference_time  \
# 0  count = 1   78.10 ± 1.67   0.00e+00 ± 0.00e+00  4.21e-04 ± 1.14e-05
# 1  count = 2  134.70 ± 0.35   0.00e+00 ± 0.00e+00  4.64e-04 ± 3.30e-05
# 2  count = 3  189.35 ± 0.45   0.00e+00 ± 0.00e+00  4.51e-04 ± 9.20e-06
#
#     mean_rewards          loss              flops        parameters
# 0   89.37 ± 5.97  -0.03 ± 0.18   32.78 ± 4.34e-15  14.98 ± 1.09e-15
# 1  104.71 ± 2.74  -0.44 ± 0.14  102.14 ± 0.00e+00  48.26 ± 0.00e+00
# 2  100.69 ± 3.55  -0.80 ± 0.13  171.52 ± 0.00e+00  81.54 ± 8.68e-15
