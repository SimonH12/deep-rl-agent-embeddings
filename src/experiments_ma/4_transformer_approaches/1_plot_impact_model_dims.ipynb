# %%
import os, sys
import matplotlib.pyplot as plt

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1

plt.rcParams.update({
    'figure.dpi': 300,
    'axes.labelsize': 30.0,
    'axes.titlesize': 30.0,
    'axes.labelweight': 'normal',
    'axes.linewidth': 1.25,
    'legend.fontsize': 25,
    'legend.title_fontsize': 18.0,
    'xtick.labelsize': 30,
    'ytick.labelsize': 30,
    'lines.linewidth': 2.0,
    'lines.markersize': 6.0,
    'grid.color': '.8',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
})

if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig
from src.utils import ExperimentUtils

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/1_set_transformer_model_dims.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Model Dimensions', legend='Model Dim')
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/1_set_transformer_og_model_dims.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Model Dimensions', legend='Model Dim')
print(suite_utils.create_table_with_confidence())
# Out:
#        Experiment  training_time training_memory_usage       inference_time  \
# 0  model_dim = 16  125.91 ± 3.55   0.00e+00 ± 0.00e+00  5.01e-04 ± 3.61e-05
# 1  model_dim = 32  314.27 ± 1.11   0.00e+00 ± 0.00e+00  5.49e-04 ± 4.59e-05
# 2  model_dim = 48  555.79 ± 0.61   0.00e+00 ± 0.00e+00  5.45e-04 ± 3.83e-05
# 3  model_dim = 64  586.37 ± 1.77   0.00e+00 ± 0.00e+00  5.27e-04 ± 4.74e-05
#
#     mean_rewards          loss              flops         parameters
# 0   92.29 ± 5.60  -0.33 ± 0.32   33.18 ± 0.00e+00   15.68 ± 1.09e-15
# 1   91.28 ± 8.64  -0.36 ± 0.30  114.28 ± 0.00e+00   56.96 ± 0.00e+00
# 2  100.41 ± 3.53  -1.01 ± 0.15  243.30 ± 1.74e-14  123.84 ± 8.68e-15
# 3  100.68 ± 3.82  -0.97 ± 0.19  420.26 ± 3.47e-14  216.32 ± 0.00e+00

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/1_sab_transformer_model_dims.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Model Dimensions', legend='Model Dim')
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/4_transformer_approaches/saved_experiments/1_isab_transformer_model_dims.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Model Dimensions', legend='Model Dim')
print(suite_utils.create_table_with_confidence())
