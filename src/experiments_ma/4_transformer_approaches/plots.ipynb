# %%
import os, sys
import torch
import matplotlib.pyplot as plt
import seaborn as sns

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1

plt.rcParams.update({
    'figure.dpi': 600,
    'axes.labelsize': 18.0,
    'axes.titlesize': 18.0,
    'axes.labelweight': 'normal',
    'axes.linewidth': 1.25,
    'legend.fontsize': 16.5,
    'legend.title_fontsize': 18.0,
    'xtick.labelsize': 16.5,
    'ytick.labelsize': 16.5,
    'lines.linewidth': 2.0,
    'lines.markersize': 6.0,
    'grid.color': '.8',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
})


if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig
from src.utils import ExperimentUtils

# %%
suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/old/set_sabs_2.csv')
suite_utils.save_df_to_file()
print(suite_utils.create_table_with_confidence())

print()
print()

suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/old/set_sabs_1.csv')
suite_utils.save_df_to_file()
print(suite_utils.create_table_with_confidence())

print()
print()

suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/old/set_sabs_0.csv')
suite_utils.save_df_to_file()
print(suite_utils.create_table_with_confidence())
# Out:
#      Experiment  training_time training_memory_usage       inference_time  \
# 0  n_agents = 5  182.84 ± 5.03   0.00e+00 ± 0.00e+00  5.03e-04 ± 3.83e-05
#
#    mean_rewards          loss              flops        parameters
# 0  98.77 ± 2.31  -0.63 ± 0.14  110.50 ± 0.00e+00  59.78 ± 4.34e-15
#
#
#      Experiment   training_time training_memory_usage       inference_time  \
# 0  n_agents = 5  222.44 ± 20.08   0.00e+00 ± 0.00e+00  6.45e-04 ± 5.38e-05
#
#    mean_rewards          loss             flops        parameters
# 0  99.80 ± 2.31  -0.95 ± 0.17  93.22 ± 0.00e+00  51.32 ± 4.34e-15
#
#
#      Experiment   training_time training_memory_usage       inference_time  \
# 0  n_agents = 5  189.25 ± 13.32   0.00e+00 ± 0.00e+00  7.46e-04 ± 5.58e-05
#
#     mean_rewards          loss             flops        parameters
# 0  101.17 ± 3.77  -0.64 ± 0.11  69.86 ± 0.00e+00  39.84 ± 4.34e-15

# %%
suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/transformer_impact_max_num5710.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of Epochs')
print(suite_utils.create_table_with_confidence())
# Out:
#         Experiment   training_time training_memory_usage       inference_time  \
# 0   max_agents = 5  1350.66 ± 9.57   5.52e+00 ± 0.00e+00  1.26e-03 ± 2.35e-05
# 1   max_agents = 7  1397.56 ± 2.51   5.52e+00 ± 0.00e+00  1.38e-03 ± 2.23e-05
# 2  max_agents = 10  1470.24 ± 3.03   5.52e+00 ± 0.00e+00  1.36e-03 ± 3.24e-05
#
#    mean_rewards         loss
# 0  95.36 ± 3.83  0.13 ± 0.39
# 1  94.87 ± 3.39  0.30 ± 0.11
# 2  95.22 ± 3.01  0.03 ± 0.12

# %%
suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/transformer_impact_max_num5710.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of Epochs')
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/src/experiments_ma/4_transformer_approaches/saved_experiments/set_transformer_inducing_points.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(xlabel='Number of Epochs')
print(suite_utils.create_table_with_confidence())
# Out:
#             Experiment   training_time training_memory_usage  \
# 0  inducing_points = 1  329.09 ± 11.04   0.00e+00 ± 0.00e+00
# 1  inducing_points = 2   339.57 ± 1.20   0.00e+00 ± 0.00e+00
# 2  inducing_points = 3   347.94 ± 2.46   0.00e+00 ± 0.00e+00
# 3  inducing_points = 4   361.44 ± 1.94   0.00e+00 ± 0.00e+00
#
#         inference_time   mean_rewards          loss
# 0  9.74e-04 ± 3.03e-05   96.78 ± 2.51  -0.49 ± 0.20
# 1  1.02e-03 ± 5.29e-05   95.74 ± 6.47  -0.33 ± 0.33
# 2  1.06e-03 ± 8.07e-05   97.99 ± 3.65  -0.59 ± 0.22
# 3  1.07e-03 ± 4.74e-05  101.52 ± 6.72  -0.46 ± 0.40
