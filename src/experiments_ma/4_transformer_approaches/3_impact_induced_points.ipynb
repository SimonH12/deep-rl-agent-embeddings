# %%
import os, sys
import torch

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1


if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig, EmbeddingStrategy
from src.experiments import ExperimentSuite
from src.utils import ExperimentUtils



def tune_num_heads(strategy, file_name, list, model_dims, heads):
    url = "saved_experiments" + "/" + file_name
    base_config_balance_5_agents = PPOConfig(
        n_agents=5, scenario_name='balance', decentralized_execution=True, attention_heads=heads,
        max_steps=200, strategy=strategy, profile=False, model_dim=model_dims,
    )

    param_grid = {
        "inducing_points": list
    }
    my_device = torch.device("cpu")
    suite = ExperimentSuite(base_config=base_config_balance_5_agents, param_grid=param_grid, name="test_all", device=my_device)
    suite.run_all_confidence(k=10)
    suite_utils = ExperimentUtils(path=url, experiment_suite=suite)
    suite_utils.save_df_to_file()
    suite_utils.plot_experiment_suite_df()
    suite_utils.create_table_with_confidence()

# %%
tune_num_heads(EmbeddingStrategy.SAB_TRANSFORMER, '3_sab_transformer_inducing_points12.csv', list=[1,2], model_dims=64, heads=1)
# Out:
# 2025-08-04 15:29:45,877 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 15:29:46,058 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 105.08464050292969: 100%|██████████| 80/80 [02:57<00:00,  2.22s/it]
# 2025-08-04 15:32:43,960 [torchrl][INFO] Training time: 120.04 seconds
# 2025-08-04 15:32:43,965 [torchrl][INFO] macs: 51.07 MMac  Params: 24.13 k
# 2025-08-04 15:32:44,793 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 15:32:44,829 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 106.95909118652344: 100%|██████████| 80/80 [03:13<00:00,  2.42s/it]
# 2025-08-04 15:35:58,696 [torchrl][INFO] Training time: 129.94 seconds
# 2025-08-04 15:35:58,701 [torchrl][INFO] macs: 51.07 MMac  Params: 24.13 k
# 2025-08-04 15:35:59,570 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 15:35:59,609 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 109.61222076416016: 100%|██████████| 80/80 [03:13<00:00,  2.42s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.SAB_TRANSFORMER, '3_sab_transformer_inducing_points34.csv', list=[3,4], model_dims=64, heads=1)
# Out:
# 2025-08-04 16:35:02,556 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 16:35:02,607 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 105.08464050292969: 100%|██████████| 80/80 [03:15<00:00,  2.45s/it]
# 2025-08-04 16:38:18,351 [torchrl][INFO] Training time: 131.50 seconds
# 2025-08-04 16:38:18,357 [torchrl][INFO] macs: 51.07 MMac  Params: 24.13 k
# 2025-08-04 16:38:19,246 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 16:38:19,283 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 106.95909118652344: 100%|██████████| 80/80 [03:15<00:00,  2.44s/it]
# 2025-08-04 16:41:34,819 [torchrl][INFO] Training time: 131.24 seconds
# 2025-08-04 16:41:34,825 [torchrl][INFO] macs: 51.07 MMac  Params: 24.13 k
# 2025-08-04 16:41:35,696 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 16:41:35,733 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 109.61222076416016: 100%|██████████| 80/80 [03:15<00:00,  2.45s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.ISAB_TRANSFORMER, '3_isab_transformer_inducing_points12.csv', list=[1,2], model_dims=64, heads=1)
# Out:
# 2025-08-04 17:40:41,424 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 17:40:41,465 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 103.60740661621094: 100%|██████████| 80/80 [02:27<00:00,  1.84s/it]
# 2025-08-04 17:43:08,836 [torchrl][INFO] Training time: 82.64 seconds
# 2025-08-04 17:43:08,841 [torchrl][INFO] macs: 62.9 MMac  Params: 57.54 k
# 2025-08-04 17:43:09,724 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 17:43:09,763 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 105.7867660522461: 100%|██████████| 80/80 [02:26<00:00,  1.84s/it]
# 2025-08-04 17:45:36,760 [torchrl][INFO] Training time: 82.17 seconds
# 2025-08-04 17:45:36,766 [torchrl][INFO] macs: 62.9 MMac  Params: 57.54 k
# 2025-08-04 17:45:37,652 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 17:45:37,691 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 108.5635986328125: 100%|██████████| 80/80 [02:27<00:00,  1.84s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.ISAB_TRANSFORMER, '3_isab_transformer_inducing_points34.csv', list=[3,4], model_dims=64, heads=1)
# Out:
# 2025-08-04 18:54:12,586 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 18:54:12,629 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 98.6903076171875: 100%|██████████| 80/80 [05:11<00:00,  3.90s/it]
# 2025-08-04 18:59:24,422 [torchrl][INFO] Training time: 247.34 seconds
# 2025-08-04 18:59:24,434 [torchrl][INFO] macs: 91.68 MMac  Params: 57.79 k
# 2025-08-04 18:59:25,310 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 18:59:25,348 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 109.15142059326172: 100%|██████████| 80/80 [05:12<00:00,  3.91s/it]
# 2025-08-04 19:04:38,264 [torchrl][INFO] Training time: 248.16 seconds
# 2025-08-04 19:04:38,275 [torchrl][INFO] macs: 91.68 MMac  Params: 57.79 k
# 2025-08-04 19:04:39,174 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 19:04:39,213 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 98.57451629638672: 100%|██████████| 80/80 [05:13<00:00,  3.91s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.SET_TRANSFORMER_INV, '3_set_transformer_inducing_points12.csv', list=[1,2], model_dims=48, heads=1)
# Out:
# 2025-08-04 20:36:22,306 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 20:36:22,349 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 97.70925903320312: 100%|██████████| 80/80 [03:49<00:00,  2.87s/it]
# 2025-08-04 20:40:11,597 [torchrl][INFO] Training time: 164.42 seconds
# 2025-08-04 20:40:11,607 [torchrl][INFO] macs: 91.36 MMac  Params: 63.74 k
# 2025-08-04 20:40:12,485 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 20:40:12,526 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 105.90275573730469: 100%|██████████| 80/80 [03:50<00:00,  2.88s/it]
# 2025-08-04 20:44:02,885 [torchrl][INFO] Training time: 165.62 seconds
# 2025-08-04 20:44:02,894 [torchrl][INFO] macs: 91.36 MMac  Params: 63.74 k
# 2025-08-04 20:44:03,788 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 20:44:03,827 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 101.24658203125: 100%|██████████| 80/80 [03:50<00:00,  2.89s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.SET_TRANSFORMER_INV, '3_set_transformer_inducing_points34.csv', list=[3,4], model_dims=48, heads=1)
# Out:
# 2025-08-04 22:16:34,959 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 22:16:35,018 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 94.6025390625: 100%|██████████| 80/80 [06:15<00:00,  4.70s/it]
# 2025-08-04 22:22:50,866 [torchrl][INFO] Training time: 311.15 seconds
# 2025-08-04 22:22:50,880 [torchrl][INFO] macs: 108.02 MMac  Params: 63.94 k
# 2025-08-04 22:22:51,767 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 22:22:51,807 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 98.10472869873047: 100%|██████████| 80/80 [06:15<00:00,  4.69s/it]
# 2025-08-04 22:29:07,155 [torchrl][INFO] Training time: 310.82 seconds
# 2025-08-04 22:29:07,170 [torchrl][INFO] macs: 108.02 MMac  Params: 63.94 k
# 2025-08-04 22:29:08,050 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-04 22:29:08,089 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 97.34014892578125: 100%|██████████| 80/80 [06:14<00:00,  4.68s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.SET_TRANSFORMER_OG, '3_set_transformer_og_inducing_points12.csv', list=[1,2], model_dims=48, heads=1)
# Out:
# 2025-08-05 00:21:34,837 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 00:21:34,883 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 97.38494110107422: 100%|██████████| 80/80 [04:58<00:00,  3.73s/it]
# 2025-08-05 00:26:33,054 [torchrl][INFO] Training time: 233.43 seconds
# 2025-08-05 00:26:33,067 [torchrl][INFO] macs: 96.65 MMac  Params: 61.63 k
# 2025-08-05 00:26:33,953 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 00:26:33,993 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 102.7929916381836: 100%|██████████| 80/80 [04:58<00:00,  3.74s/it]
# 2025-08-05 00:31:32,802 [torchrl][INFO] Training time: 234.21 seconds
# 2025-08-05 00:31:32,815 [torchrl][INFO] macs: 96.65 MMac  Params: 61.63 k
# 2025-08-05 00:31:33,723 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 00:31:33,763 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 100.88349151611328: 100%|██████████| 80/80 [05:01<00:00,  3.77s/it]
# ...

# %%
tune_num_heads(EmbeddingStrategy.SET_TRANSFORMER_OG, '3_set_transformer_og_inducing_points34.csv', list=[3,4], model_dims=48, heads=1)
# Out:
# 2025-08-05 02:23:49,324 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 02:23:49,373 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 104.44804382324219: 100%|██████████| 80/80 [07:24<00:00,  5.56s/it]
# 2025-08-05 02:31:14,277 [torchrl][INFO] Training time: 380.54 seconds
# 2025-08-05 02:31:14,295 [torchrl][INFO] macs: 113.32 MMac  Params: 61.83 k
# 2025-08-05 02:31:15,174 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 02:31:15,213 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 84.99708557128906: 100%|██████████| 80/80 [07:25<00:00,  5.56s/it]
# 2025-08-05 02:38:40,395 [torchrl][INFO] Training time: 380.78 seconds
# 2025-08-05 02:38:40,410 [torchrl][INFO] macs: 113.32 MMac  Params: 61.83 k
# 2025-08-05 02:38:41,276 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-05 02:38:41,315 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 104.2459945678711: 100%|██████████| 80/80 [07:24<00:00,  5.55s/it]
# ...
