# %%
import os, sys
import torch
from zipp import FastLookup

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)


if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig, EmbeddingStrategy
from src.experiments import ExperimentSuite
from src.utils import ExperimentUtils



def tune_layer_width_wrt_encode(strategy, file_name, encode=True):
    url = "saved_experiments" + "/" + file_name
    base_config_balance_5_agents = PPOConfig(
        n_agents=5, scenario_name='balance', decentralized_execution=True,
        max_steps=200, pooling_method='mean', strategy=strategy, profile=False, use_encoder_mlp=encode
    )

    param_grid = {
        "hidden_layer_width": [16, 32, 48, 64]
    }
    my_device = torch.device("cpu")
    suite = ExperimentSuite(base_config=base_config_balance_5_agents, param_grid=param_grid, name="test_all", device=my_device)
    suite.run_all_confidence(k=10)
    suite_utils = ExperimentUtils(path=url, experiment_suite=suite)
    suite_utils.save_df_to_file()
    suite_utils.plot_experiment_suite_df()
    print(suite_utils.create_table_with_confidence())

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_SAGE, file_name='1_gsage_encode_true', encode=True)
# Out:
# 2025-08-29 12:13:59,247 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-29 12:13:59,474 [torchrl][INFO] check_env_specs succeeded!
# episode_reward_mean = 0:   0%|          | 0/80 [00:00<?, ?it/s]/opt/miniconda3/envs/ma_rl/lib/python3.9/site-packages/torch_geometric/utils/_scatter.py:79: UserWarning: There is a performance drop because we have not yet implemented the batching rule for aten::scatter_add_. Please file us an issue on GitHub so that we can prioritize its implementation. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/functorch/BatchedFallback.cpp:84.)
#   count.scatter_add_(0, index, src.new_ones(src.size(dim)))
# ...

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_GAT, file_name='1_gat_encode_true', encode=True)
# Out:
# 2025-08-29 12:17:39,430 [torchrl][INFO] check_env_specs succeeded!
# 2025-08-29 12:17:39,497 [torchrl][INFO] check_env_specs succeeded!
#
# episode_reward_mean = 0:   0%|          | 0/80 [00:00<?, ?it/s]/opt/miniconda3/envs/ma_rl/lib/python3.9/site-packages/torch_geometric/utils/_scatter.py:102: UserWarning: There is a performance drop because we have not yet implemented the batching rule for aten::scatter_reduce_.two. Please file us an issue on GitHub so that we can prioritize its implementation. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/functorch/BatchedFallback.cpp:84.)
#   return src.new_zeros(size).scatter_reduce_(
# ...

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_GAT_v2, file_name='1_gatv2_encode_true', encode=True)

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_SAGE, file_name='1_gsage_encode_false', encode=False)

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_GAT, file_name='1_gat_encode_false', encode=False)

# %%
tune_layer_width_wrt_encode(EmbeddingStrategy.GRAPH_GAT_v2, file_name='1_gatv2_encode_false', encode=False)
