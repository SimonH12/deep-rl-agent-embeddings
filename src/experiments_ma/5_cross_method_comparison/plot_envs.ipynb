# %%
import os, sys
import torch
import matplotlib.pyplot as plt

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1

plt.rcParams.update({
    'figure.dpi': 100,
    'axes.labelsize': 30.0,
    'axes.titlesize': 30.0,
    'axes.labelweight': 'normal',
    'axes.linewidth': 1.25,
    'legend.fontsize': 20,
    'legend.title_fontsize': 18.0,
    'xtick.labelsize': 23,
    # 'xtick.labelsize': 30,
    'ytick.labelsize': 30,
    'lines.linewidth': 2.0,
    'lines.markersize': 6.0,
    'grid.color': '.8',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
})

if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig
from src.utils import ExperimentUtils

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/5_cross_method_comparison/saved_experiments/1_balance_all.csv', map_strategy_names=True)
suite_utils.plot_experiment_suite_df(xlabel='Strategies', extract=False, shorten=True, rotate=True, cols=2)
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/5_cross_method_comparison/saved_experiments/5_navigation_all_ctce.csv', map_strategy_names=True)
suite_utils.plot_experiment_suite_df(xlabel='Strategies', extract=False, y_limits=(-6,6), logscale=False, rotate=True, shorten=True, cols=2, remove_legend=True) # , max_x_tick=30)
# max_x_ticks = 20
print(suite_utils.create_table_with_confidence())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/5_cross_method_comparison/saved_experiments/5_navigation_all_ctce.csv', map_strategy_names=True)
# ----> 2 suite_utils.plot_experiment_suite_df(xlabel='Strategies', extract=False, y_limits=(-6,6), logscale=False, rotate=True, shorten=True, cols=2, remove_legend=True) # , max_x_tick=30)
#       3 # max_x_ticks = 20
#       4 print(suite_utils.create_table_with_confidence())
#
# File ~/Desktop/MA/swarm-rl/src/utils.py:172, in ExperimentUtils.plot_experiment_suite_df(self, confidence, max_x_tick, xlabel, extract, y_limits, legend, cols, remove_legend, logscale, rotate, shorten, leg_location)
#     169 plt.grid(True)
#     171 if legend is not None:
# --> 172     match = re.search(r'\d+', name).group()
# ...

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/5_cross_method_comparison/saved_experiments/5_give_way_all_ctce.csv', map_strategy_names=True)
suite_utils.plot_experiment_suite_df(xlabel='Strategies', extract=False, shorten=True, cols=2, rotate=True,  y_limits=(-20,60), remove_legend=True)
print(suite_utils.create_table_with_confidence())

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/5_cross_method_comparison/saved_experiments/5_balance_all_ctce.csv', map_strategy_names=True)
suite_utils.plot_experiment_suite_df(xlabel='Strategies', extract=False, shorten=True, rotate=True, cols=2, remove_legend=True)
print(suite_utils.create_table_with_confidence())
