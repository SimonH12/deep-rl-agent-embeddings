# %%
import os, sys
import torch
import matplotlib.pyplot as plt

dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
dir0 = os.path.dirname(dir1)  # One level above dir1

plt.rcParams.update({
    'figure.dpi': 600,
    'axes.labelsize': 30.0,
    'axes.titlesize': 30.0,
    'axes.labelweight': 'normal',
    'axes.linewidth': 1.25,
    'legend.fontsize': 25,
    'legend.title_fontsize': 18.0,
    'xtick.labelsize': 30,
    'ytick.labelsize': 30,
    'lines.linewidth': 2.0,
    'lines.markersize': 6.0,
    'grid.color': '.8',
    'grid.linestyle': '-',
    'grid.linewidth': 1.0,
})

if dir1 not in sys.path: sys.path.append(dir0)

from src.config import PPOConfig
from src.utils import ExperimentUtils

# %%
suite_utils = ExperimentUtils(path='/Users/simonhampp/Desktop/MA/swarm-rl/src/experiments_ma/1_concat_tune/saved_experiments/concat_tune_epochs.csv')
suite_utils.save_df_to_file()
suite_utils.plot_experiment_suite_df(max_x_tick=100, xlabel='Number of Epochs', legend='Epochs', cols=2)
print(suite_utils.create_table_with_confidence())
# Out:
#         Experiment  training_time training_memory_usage       inference_time  \
# 0   num_epochs = 2   24.03 ± 2.29     330.50 ± 0.00e+00  5.86e-04 ± 8.84e-05
# 1   num_epochs = 4   39.33 ± 2.58     660.62 ± 0.00e+00  5.91e-04 ± 8.81e-05
# 2   num_epochs = 6   51.95 ± 2.72     991.49 ± 0.00e+00  5.18e-04 ± 6.68e-06
# 3   num_epochs = 8   57.73 ± 0.63    1321.17 ± 0.00e+00  4.55e-04 ± 5.55e-06
# 4  num_epochs = 10   68.54 ± 0.64    1651.27 ± 0.00e+00  4.65e-04 ± 2.09e-05
# 5  num_epochs = 20  134.00 ± 0.67    3301.71 ± 0.00e+00  4.77e-04 ± 1.04e-05
# 6  num_epochs = 30  231.14 ± 6.28    4957.08 ± 0.00e+00  5.55e-04 ± 2.33e-05
#
#     mean_rewards          loss             flops        parameters
# 0   68.59 ± 4.21   0.41 ± 0.37  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 1   93.65 ± 5.61  -0.19 ± 0.27  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 2  100.03 ± 4.91  -0.39 ± 0.19  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 3  108.91 ± 4.82  -0.93 ± 0.31  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 4  110.64 ± 5.91  -1.17 ± 0.23  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 5  114.53 ± 5.60  -1.58 ± 0.30  37.64 ± 0.00e+00  18.82 ± 0.00e+00
# 6  116.05 ± 5.57  -1.83 ± 0.30  37.64 ± 0.00e+00  18.82 ± 0.00e+00
